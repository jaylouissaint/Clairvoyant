# %%
import pandas as pd
import numpy as np

# %%
postings = pd.read_csv("/Users/aishanipradhan/Desktop/data_visualization/eda/archive/postings.csv")
postings = postings[~postings["company_name"].isna()]
postings.shape

# %%
# Uique company names from postings
unique_company_names = postings[['company_name']].drop_duplicates()
unique_company_names['company_name'] = unique_company_names['company_name'].str.strip()

# %% [markdown]
# Step1: the 44 companies identified in finance dataset
# Step 2: Find a list of child companies using openrefine
# Step 3: create a list of keywords to perform string matching (file name: parent_child_w_keywords). keywords used in list below

# %%
companies = ["rtx",
    "boeing",
    "l3harris",
    "northrop grumman",
    "general dynamics",
    "huntington ingalls",
    "transdigm",
    "textron",
    "lockheed martin",
    "broadcom",
    "nvidia",
    " cisco ",
    "apple ",
    "salesforce",
    "accenture",
    "tesla",
    "amazon",
    "netflix",
    "alphabet",
    "at&t",
    "meta ",
    "disney",
    "t-mobile us",
    "verizon",
    "charter communications",
    "comcast",
    "advanced micro devices",
    "AMD ",
    "qualcomm",
    "texas instruments",
    "intel ",
    "lam research",
    "applied materials",
    "marvell technology",
    "micron technology",
    "palantir technologies",
    "snowflake",
    "oracle",
    "palo alto networks",
    "microsoft",
    "intuit",
    "servicenow",
    "atlassian",
    "adobe"]
subs = [
    "collins aerospace",
    "pratt & whitney",
    "raytheon intelligence & space",
    "raytheon missiles & defense",
    "boeing rotorcraft systems",
    "boeing capital",
    "boeing commercial airplanes",
    "boeing phantom works",
    "boeing defense, space & security",
    "mcdonnell douglas",
    "alteon training",
    "boeing aircraft holding company",
    "jeppesen",
    "nv5 geospatial solutions",
    "aerojet rocketdyne holdings",
    "northrop grumman aeronautics systems",
    "northrop grumman defense systems",
    "northrop grumman mission systems",
    "northrop grumman space systems",
    "general dynamics electric boat",
    "gulfstream aerospace",
    "creative technology",
    "electric launch company",
    "general dynamics mission systems",
    "general atomics",
    "general dynamics land systems",
    "national steel and shipbuilding company",
    "tadpole computer",
    "bath iron works",
    "convair",
    "jet aviation",
    "aai corporation",
    "cessna",
    "avco",
    "lycoming",
    "textron marine & land systems",
    "gorham manufacturing company",
    "bell flight",
    "bostitch",
    "lockheed martin aeronautics",
    "lockheed martin missiles and fire control",
    "lockheed martin mission systems and sensors",
    "lockheed martin space",
    "nvidia",
    "icera",
    "mental images",
    "mellanox technologies",
    "scientific atlanta",
    "cerent corporation",
    "stratacom",
    "nds group",
    "tandberg",
    "webex by cisco",
    "linksys",
    "starent networks",
    "sourcefire",
    "cisco meraki",
    "appdynamics",
    "filemaker",
    "anobit",
    "beats electronics",
    "braeburn capital",
    "authentec",
    "fingerworks",
    "prismo graphics",
    "raycer",
    "schemasoft",
    "claris",
    "siri",
    "salesforce marketing cloud",
    "heroku",
    "krux",
    "tableau software",
    "clicksoftware technologies",
    "mulesoft",
    "quip",
    "demandware",
    "slack technologies",
    "vlocity",
    "accenture",
    "accenture federal services",
    "solarcity",
    "tesla grohmann automation",
    "a9.com",
    "amazon web services",
    "alexa internet",
    "zappos",
    "imdb.com",
    "twitch interactive",
    "amazon books",
    "amazon games",
    "amazon lab126",
    "amazon publishing",
    "amazon robotics",
    "amazon mgm studios",
    "audible",
    "body labs",
    "book depository",
    "box office mojo",
    "digital photography review",
    "goodreads",
    "graphiq",
    "ring",
    "whole foods market",
    "woot",
    "diapers.com",
    "amazon prime video",
    "sqrrl",
    "double helix games",
    "amazon logistics",
    "amazon air",
    "amazon prime air",
    "amazon technologies",
    "mgm holdings",
    "amazon fresh",
    "albuquerque studios",
    "storybots",
    "google",
    "x development",
    "gv",
    "calico",
    "google nest",
    "google fiber",
    "loon",
    "wing",
    "owlchemy labs",
    "waymo",
    "waymo holding",
    "xxvi holdings",
    "cricket wireless",
    "at&t mobility",
    "at&t corporation",
    "at&t labs",
    "at&t intellectual property marketing",
    "at&t properties",
    "at&t intellectual property i",
    "at&t intellectual property ii",
    "directv",
    "dimacs",
    "warner media",
    "bell labs",
    "appnexus",
    "at&t foundation",
    "indiana bell",
    "illinois bell",
    "reality labs",
    "instagram",
    "meta spark studio",
    "national geographic partners",
    "iWireless",
    "metro by t-mobile",
    "aol",
    "verizon",
    "verizon pennsylvania",
    "insight communications",
    "spectrum",
    "time warner cable",
    "nbcuniversal",
    "comcast ventures",
    "semicro",
    "ati technologies",
    "xilinx",
    "qualcomm atheros",
    "burr-brown corporation",
    "luminary micro",
    "national semiconductor",
    "chipcon",
    "texas instruments",
    "intel capital",
    "wind river systems",
    "havok",
    "mcafee",
    "mobileye",
    "intel architecture labs",
    "lam research",
    "applied materials",
    "elpida memory",
    "numonyx",
    "displaytech incorporated",
    "palantir technologies",
    "sun microsystems",
    "jd edwards",
    "xbox game studios",
    "avanade",
    "lionhead studios",
    "microsoft mobile",
    "microsoft production studios",
    "rare ltd",
    "ensemble studios",
    "microsoft store",
    "proclarity",
    "danger",
    "perceptive pixel",
    "greenbutton",
    "microsoft research asia",
    "sysinternals",
    "massive incorporated",
    "jellyfish.com",
    "powerset",
    "tellme networks",
    "visio corporation",
    "aquantive",
    "turn 10 studios",
    "fast search & transfer",
    "digital anvil",
    "razorfish",
    "datallegro",
    "microsoft kids",
    "linkedIn corporation",
    "skype technologies",
    "clipchamp",
    "nuance communications",
    "activision blizzard",
    "marketo",
    "adobe creative cloud",
    "warnermedia",
    "whatsapp",
    "beat games",
    "yahoo"
]

# %%
def find_comp_match(name):
    name_lower = str(name).lower()
    for c in companies:
        if c in name_lower:
            return c
    return "None" 

unique_company_names["comp_mapping"] = unique_company_names["company_name"].apply(find_comp_match)

def find_match_subs(name):
    name_lower = str(name).lower()
    for c in subs:
        if c in name_lower:
            return c
    return "None" 

unique_company_names["sub_mapping"] = unique_company_names["company_name"].apply(find_match_subs)

# %%
unique_company_names.to_csv("/Users/aishanipradhan/Desktop/company_name_mappings_manual.csv", index = False)

# %% [markdown]
# After this, a manual check was done to only include correctly mapped names in file company_name_mapping_manual. Final mapping list is called finance_mapping.

# %% [markdown]
# # Supplemental

# %%
# Generating CSV with matched finance_name_keyword and child_keyword
import pandas as pd
import os

# Load the CSV file
df = pd.read_csv("/Users/aishanipradhan/Desktop/finance_names.csv")

# Provided keyword lists
companies = ["rtx",
    "boeing",
    "l3harris",
    "northrop grumman",
    "general dynamics",
    "huntington ingalls",
    "transdigm",
    "textron",
    "lockheed martin",
    "broadcom",
    "nvidia",
    " cisco ",
    "apple",
    "salesforce",
    "accenture",
    "tesla",
    "amazon",
    "netflix",
    "alphabet",
    "at&t",
    "meta ",
    "disney",
    "t-mobile us",
    "verizon",
    "charter communications",
    "comcast",
    "advanced micro devices",
    "AMD",
    "qualcomm",
    "texas instruments",
    "intel",
    "lam research",
    "applied materials",
    "marvell technology",
    "micron technology",
    "palantir technologies",
    "snowflake",
    "oracle",
    "palo alto networks",
    "microsoft",
    "intuit",
    "servicenow",
    "atlassian",
    "adobe"]
subs = [
    "collins aerospace",
    "pratt & whitney",
    "raytheon intelligence & space",
    "raytheon missiles & defense",
    "boeing rotorcraft systems",
    "boeing capital",
    "boeing commercial airplanes",
    "boeing phantom works",
    "boeing defense, space & security",
    "mcdonnell douglas",
    "alteon training",
    "boeing aircraft holding company",
    "jeppesen",
    "nv5 geospatial solutions",
    "aerojet rocketdyne holdings",
    "northrop grumman aeronautics systems",
    "northrop grumman defense systems",
    "northrop grumman mission systems",
    "northrop grumman space systems",
    "general dynamics electric boat",
    "gulfstream aerospace",
    "creative technology",
    "electric launch company",
    "general dynamics mission systems",
    "general atomics",
    "general dynamics land systems",
    "national steel and shipbuilding company",
    "tadpole computer",
    "bath iron works",
    "convair",
    "jet aviation",
    "aai corporation",
    "cessna",
    "avco",
    "lycoming",
    "textron marine & land systems",
    "gorham manufacturing company",
    "bell flight",
    "bostitch",
    "lockheed martin aeronautics",
    "lockheed martin missiles and fire control",
    "lockheed martin mission systems and sensors",
    "lockheed martin space",
    "nvidia",
    "icera",
    "mental images",
    "mellanox technologies",
    "scientific atlanta",
    "cerent corporation",
    "stratacom",
    "nds group",
    "tandberg",
    "webex by cisco",
    "linksys",
    "starent networks",
    "sourcefire",
    "cisco meraki",
    "appdynamics",
    "filemaker",
    "anobit",
    "beats electronics",
    "braeburn capital",
    "authentec",
    "fingerworks",
    "prismo graphics",
    "raycer",
    "schemasoft",
    "claris",
    "siri",
    "salesforce marketing cloud",
    "heroku",
    "krux",
    "tableau software",
    "clicksoftware technologies",
    "mulesoft",
    "quip",
    "demandware",
    "slack technologies",
    "vlocity",
    "accenture",
    "accenture federal services",
    "solarcity",
    "tesla grohmann automation",
    "a9.com",
    "amazon web services",
    "alexa internet",
    "zappos",
    "imdb.com",
    "twitch interactive",
    "amazon books",
    "amazon games",
    "amazon lab126",
    "amazon publishing",
    "amazon robotics",
    "amazon mgm studios",
    "audible",
    "body labs",
    "book depository",
    "box office mojo",
    "digital photography review",
    "goodreads",
    "graphiq",
    "ring",
    "whole foods market",
    "woot",
    "diapers.com",
    "amazon prime video",
    "sqrrl",
    "double helix games",
    "amazon logistics",
    "amazon air",
    "amazon prime air",
    "amazon technologies",
    "mgm holdings",
    "amazon fresh",
    "albuquerque studios",
    "storybots",
    "google",
    "x development",
    "gv",
    "calico",
    "google nest",
    "google fiber",
    "loon",
    "wing",
    "owlchemy labs",
    "waymo",
    "waymo holding",
    "xxvi holdings",
    "cricket wireless",
    "at&t mobility",
    "at&t corporation",
    "at&t labs",
    "at&t intellectual property marketing",
    "at&t properties",
    "at&t intellectual property i",
    "at&t intellectual property ii",
    "directv",
    "dimacs",
    "warner media",
    "bell labs",
    "appnexus",
    "at&t foundation",
    "indiana bell",
    "illinois bell",
    "reality labs",
    "instagram",
    "meta spark studio",
    "national geographic partners",
    "iWireless",
    "metro by t-mobile",
    "aol",
    "verizon",
    "verizon pennsylvania",
    "insight communications",
    "spectrum",
    "time warner cable",
    "nbcuniversal",
    "comcast ventures",
    "semicro",
    "ati technologies",
    "xilinx",
    "qualcomm atheros",
    "burr-brown corporation",
    "luminary micro",
    "national semiconductor",
    "chipcon",
    "texas instruments",
    "intel capital",
    "wind river systems",
    "havok",
    "mcafee",
    "mobileye",
    "intel architecture labs",
    "lam research",
    "applied materials",
    "elpida memory",
    "numonyx",
    "displaytech incorporated",
    "palantir technologies",
    "sun microsystems",
    "jd edwards",
    "xbox game studios",
    "avanade",
    "lionhead studios",
    "microsoft mobile",
    "microsoft production studios",
    "rare ltd",
    "ensemble studios",
    "microsoft store",
    "proclarity",
    "danger",
    "perceptive pixel",
    "greenbutton",
    "microsoft research asia",
    "sysinternals",
    "massive incorporated",
    "jellyfish.com",
    "powerset",
    "tellme networks",
    "visio corporation",
    "aquantive",
    "turn 10 studios",
    "fast search & transfer",
    "digital anvil",
    "razorfish",
    "datallegro",
    "microsoft kids",
    "linkedIn corporation",
    "skype technologies",
    "clipchamp",
    "nuance communications",
    "activision blizzard",
    "marketo",
    "adobe creative cloud",
    "warnermedia",
    "whatsapp",
    "beat games",
    "yahoo"
]

# Normalize keywords for matching
companies = [c.strip().lower() for c in companies]
subs = [s.strip().lower() for s in subs]

# Function to find matching keyword
def find_keyword(text, keywords):
    text = str(text).lower()
    for keyword in keywords:
        if keyword in text:
            return keyword
    return ""

# Apply matching
df["finance_name_keyword"] = df["finance_name"].apply(lambda x: find_keyword(x, companies))
df["child_keyword"] = df["child"].apply(lambda x: find_keyword(x, subs))

# Save to CSV
output_path = "/Users/aishanipradhan/Desktop/finance_names_with_keywords.csv"
df.to_csv(output_path, index=False)

output_path
# Out:
# '/Users/aishanipradhan/Desktop/finance_names_with_keywords.csv'
